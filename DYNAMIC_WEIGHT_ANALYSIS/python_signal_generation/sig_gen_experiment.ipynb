# %% [markdown]
# # <u>IMPORTS

# %%
import numpy as np 
from scipy.integrate import solve_ivp
from scipy import signal
import matplotlib.pyplot as plt
import seaborn as sns
import math as m
import sys
import os

# %% [markdown]
# # <u>TESTING PARAMETERS

# %%
# set common paramaters between tests
duration = 10 # seconds
sampling_rate = 1000 # hertz
no_samples = int(duration/(1/sampling_rate))
t = np.linspace(0, duration ,no_samples)
weight = 3.5

# %% [markdown]
# # <u>FUNCTIONS

# %% [markdown]
# ## NOISE

# %%
def addNoise(sig):    
    mean = 0
    std_dev = 1
    noise = np.random.normal(mean, std_dev, len(sig))
    return sig + noise

# %% [markdown]
# ## CONSTANT WEIGHT

# %%
def constantWeight(t,w, time_before = 0):
    # get the sampling period
    signal = np.full_like(t, w*9.8)
    return signal

# %% [markdown]
# ## CREATE DAMPED OSCILATION

# %% [markdown]
# #### FUNCTION

# %%
def DampOscilation(t,gamma,omega_sqr):
    # gamma sets how long it takes for oscilations to dampen
    # omega squared changes how quickly the oscilations disapear

    y = [0,1]
    def sho(t,y):
        solution = (y[1],(-gamma*y[1]-omega_sqr*y[0]))
        return solution
    solution = solve_ivp(sho, [0,t.size], y0 = y, t_eval = t)

    # scale the oscilation so the max value is 1
    osc = solution.y[0]
    osc = osc * 1/np.max(osc)

    return osc

# %% [markdown]
# #### EXAMPLE

# %%
# generate oscillation
osc = DampOscilation(t,2,100)

# plot
plt.plot(t,osc)
plt.ylabel("Position")
plt.xlabel("Time")
plt.title('Damped Oscillator', fontsize = 20)
plt.show()

# %% [markdown]
# ## LANDING

# %% [markdown]
# #### FUNCTION

# %%
def Landing(t,start_time):
    # System parameters
    damping_ratio = 0.4  # alters the rate of damping
    natural_frequency = 6  # alters the frequency of oscilations

    # create transfer function for second order underdamped system
    numerator = [natural_frequency**2]
    denominator = [1, 2*damping_ratio*natural_frequency, natural_frequency**2]
    system = signal.TransferFunction(numerator, denominator)

    # calculate landing time
    if start_time > t[t.size-1]:
        print("Start time is outside signal time.")
        sys.exit()
    start_index = np.abs(t - start_time).argmin()
    no_samples = int(t.size - start_index)
    t_osc = np.linspace(t[start_index], t[t.size-1],no_samples)

    # compute the step response
    time, osc = signal.step(system, T=t_osc)

    # zero pad the beginning of the oscilation
    osc = np.pad(osc, (start_index, 0), mode='constant')

    return osc

# %% [markdown]
# #### EXAMPLE

# %%
# generate landing example
landing = Landing(t,1)

plt.plot(t,landing)
plt.ylabel("Force")
plt.xlabel("Time")
plt.title('Landing', fontsize = 20)
plt.show()

# %% [markdown]
# ## TAKE-OFF

# %% [markdown]
# #### FUNCTION

# %%
def TakeOff(t):
    # System parameters
    damping_ratio = 0.3  # alters the rate of damping
    natural_frequency = 10  # alters the frequency of oscilations

    # create transfer function for second order underdamped system
    numerator = [natural_frequency**2]
    denominator = [1, 2*damping_ratio*natural_frequency, natural_frequency**2]
    system = signal.TransferFunction(numerator, denominator)

    # compute the step response
    time, osc = signal.step(system, T=t)

    # invert oscilation
    osc = osc[::-1]

    return osc

# %% [markdown]
# #### EXAMPLE

# %%
# generate landing example
take_off = TakeOff(t)
plt.plot(t,take_off)
plt.ylabel("Force")
plt.xlabel("Time")
plt.title('Take Off', fontsize = 20)
plt.show()

# %% [markdown]
# ### WALKING

# %%
def Step(samp_per,step_dur):
    t_step = np.linspace(0, step_dur, m.ceil(step_dur/samp_per) + 1)

    outer_freq = 1/(2*step_dur)
    outer_sig =  np.sin(2 * np.pi * outer_freq * t_step)

    base_freq = 5 * outer_freq
    base_sig = np.sin(2 * np.pi * base_freq * t_step)

    step = outer_sig * base_sig

    return step * -1

def addSteps(t,f,step_times,step_dur,weight,weight_perc):
    samp_per = t[1] - t[0]
    for step_time in step_times:
        step = Step(samp_per,step_dur) * weight * weight_perc * 9.8
        start_index = int(step_time/samp_per)
        end_index = start_index + int(step_dur/samp_per)
        for i in range(start_index,end_index):
            f[i] = f[i] + step[i-start_index]

    return f

# %%
# generate walking
weight_force = constantWeight(t,0)
steps = addSteps(t,weight_force,[2,6],2,weight,0.1)
plt.plot(t,steps)
plt.ylabel("Force")
plt.xlabel("Time")
plt.title('Steps', fontsize = 20)
plt.show()

# %% [markdown]
# ## SIMULATED SIGNAL

# %%
# generate walking
sim = Landing(t,0)
sim = sim * TakeOff(t) * weight * 9.8
sim = addSteps(t,sim,[2,6],2,weight,0.5)
sim = addNoise(sim)
plt.plot(t,sim)
plt.ylabel("Force")
plt.xlabel("Time")
plt.title('Steps', fontsize = 20)
plt.show()

# %%
np.savetxt('signal.txt', sim)

# %% [markdown]
# # <u> ADC SIMULATION

# %% [markdown]
# ## DOWNSAMPLE

# %% [markdown]
# ### FUNCTION

# %%
def downSample(t,sig,new_freq):
    # no_samp_new = m.ciel(sig_dur / new_samp_per)
    # t_new = 

    # get the number of intervals in new sampling period
    new_samp_per = 1/new_freq
    samp_per_old = t[1] - t[0]
    no_int = int(m.floor(new_samp_per/samp_per_old))
    
    # create new time axis
    sig_dur = t[t.size-1]
    no_samp_new = int(m.floor(t.size/no_int))
    t_new = np.linspace(0,sig_dur,no_samp_new)

    # create new signal
    sig_new = np.zeros(t_new.size)
    for i in range(0,t_new.size):
        t_new[i] = t[i*no_int]
        sig_new[i] = sig[i*no_int]

    return t_new, sig_new

# %% [markdown]
# ### EXAMPLE

# %%
# generate walking
t_down,sig_down = downSample(t,sim,10)
plt.plot(t_down,sig_down)
plt.ylabel("Force")
plt.xlabel("Time")
plt.title('Steps', fontsize = 20)
plt.show()

# %% [markdown]
# ## CONVERT TO ADC OUT

# %% [markdown]
# ### FUNCTION

# %%
def toADCOut(t,sig,scale,offset,adc_samp_freq):
    t_down, sig_down = downSample(t,sig,adc_samp_freq)
    sig_out = ((sig_down + offset) * scale).astype(int)
    return t_down, sig_out

# %% [markdown]
# ### EXAMPLE

# %%
# generate walking
t_down, sim_adc = toADCOut(t,sim,2280,20,10)
plt.plot(t_down,sim_adc)
plt.ylabel("Force")
plt.xlabel("Time")
plt.title('Steps', fontsize = 20)
plt.show()

# %%
np.savetxt('signal_adc.txt', sim_adc)

# %% [markdown]
# # <u>GENERATE TEST SIGNALS

# %% [markdown]
# ## SAVE SIGNAL

# %% [markdown]
# ### FUNCTION

# %%
def save_sig(title, weight, samp_freq, sig, offset, scale, file_path=""):
    # add header information to the content
    content = f"Title: {title}\nSampling Frequency: {samp_freq} Hz\nWeight: {weight}\nOffset: {offset}\nScale: {scale}\n"
    
    # add signal to content
    content += "\n".join(str(int(value)) for value in sig)

    # write to the file
    with open(file_path, "w") as file:
        file.write(content)

# %% [markdown]
# ### EXAMPLE IDEAL SITUATION

# %%
save_sig("Lands at start, takes two steps and takes off",weight,10,sim_adc,20,2280,"test_signals/land_2_steps_takeoff.txt")

# %% [markdown]
# ## LANDING

# %%
# create time

# %% [markdown]
# ## STEPS

# %% [markdown]
# ## TAKEOFF

# %% [markdown]
# ## RAPID TAKEOFF AND LANDING

# %% [markdown]
# ## SPORADIC

# %% [markdown]
# ## TWO BIRDS

# %% [markdown]
# ## SMALLER ANIMAL
